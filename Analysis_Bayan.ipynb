# %% [markdown]
# <a href="https://colab.research.google.com/github/nadaAlruwaythi/Hackathon-Bayan/blob/main/Analysis_Bayan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# * 1- what are the most popular types of food restaurant
# * 2- are the restaurants suitable for the family or not in terms of the privacy
# * 3- is the restaurant  location clear or not
# * 4-are the restaurant price suitable for everyone!

# %%
df=pd.read_csv('resturantsframe-Clean.csv')
df.head()
# Out:
#                                     address_line1  \
# 0                                  King Saud Road
# 1  Prince Musaed Street Dughaither Leisure Island
# 2                            Prince Musaid Street
# 3        King Saud Road Kempinski Al Othman Hotel
# 4                  Fouad Center _ Corniche Street
#
#                    address_line2              city  \
# 0   Al Khobar 31952 Saudi Arabia  Eastern_Province
# 1         Al Khobar Saudi Arabia  Eastern_Province
# 2                34425 Al Khobar  Eastern_Province
# 3   Al Khobar 31952 Saudi Arabia  Eastern_Province
# 4         Al Khobar Saudi Arabia  Eastern_Province
#
#                                            food_type      food_type1  \
# 0  , International, Vegan Options, Vegetarian Fri...   International
# 1            , Seafood, International, Mediterranean         Seafood
# 2                           , Japanese, Sushi, Asian        Japanese
# 3                           , Italian, Pizza, Romana         Italian
# ...

# %%
df.city.value_counts()
# Out:
# Jeddah              634
# Eastern_Province    633
# Riyadh              563
# Name: city, dtype: int64

# %%
figsize=(6,6)
plt.hist(df.city);

# %%
(df.groupby(['city'])).
# Out:
# city
# Eastern_Province    633
# Jeddah              634
# Riyadh              563
# dtype: int64

# %%
mask=((df['city']=='Riyadh'))
df[mask].head(2)
# Out:
#          address_line1        address_line2    city  \
# 1267  The Ritz-Carlton   Riyadh Mekkah Road  Riyadh
# 1268       Levels Mall              Level 1  Riyadh
#
#                                            food_type      food_type1  \
# 1267  , Mediterranean, Middle Eastern, International   Mediterranean
# 1268            , Indian, Asian, Vegetarian Friendly          Indian
#
#                                                location number_of_reviews  \
# 1267  The Ritz-Carlton, Riyadh Mekkah Road, Al Hada ...             1,316
# 1268  Levels Mall, Level 1, Exit 5 Off Northern Ring...               278
#
#                   opening_hour                           out_of  \
# 1267    Open Now:See all hours  1 of 79 International in Riyadh
# 1268  Closed Now:See all hours         1 of 69 Indian in Riyadh
#
#                 phone  price_range                      restaurant_name  \
# 1267  966 11 802 8333   173 -  324                           Al Orjouan
# ...

# %%
df.dropna(inplace=True)

# %%
df.dropna()
# Out:
#                                  address_line1                  address_line2  \
# 0                               King Saud Road   Al Khobar 31952 Saudi Arabia
# 2                         Prince Musaid Street                34425 Al Khobar
# 3     King Saud Road Kempinski Al Othman Hotel   Al Khobar 31952 Saudi Arabia
# 10               Prince Musaed Street Cross 10   Al Khobar 31952 Saudi Arabia
# 11                       Faisal Al Saud Street   Al Khobar 34422 Saudi Arabia
# ...                                        ...                            ...
# 1769                9097 Al Urubah Branch Road               Al Urubah Square
# 1771              4430 Imam Saud Bin Faisal Rd                       Al Malqa
# 1774                        Northern Ring Road      Riyadh 11552 Saudi Arabia
# 1776                             Khurais- Road      Riyadh 11635 Saudi Arabia
# 1778     3878 Prince Muhammad Bin Abdulaziz Rd                 As Sulimaniyah
#
# ...

# %%
# Creat new data frame of the top 10 station of daily_exits
# top10_stations=total_station_exits.groupby(['STATION'])[['DAILY_EXITS']]\
# .sum().reset_index().sort_values(by='DAILY_EXITS',ascending=False).STATION.head(10)

# top10_stations

top=df[mask].groupby(['restaurant_name'])[['price_range']]
top.head(10)
# Out:
#       price_range
# 1267   173 -  324
# 1268    50 -  200
# 1269    10 -  300
# 1270    50 -  200
# 1271    19 -  188
# ...           ...
# 1825          NaN
# 1826    11 -  489
# 1827     21 -  32
# 1828     39 -  49
# 1829     10 -  50
#
# [563 rows x 1 columns]

# %%
gro=(df[mask].groupby(['restaurant_name','price_range']).size())
gro.head()
# Out:
# restaurant_name               price_range
#   Degrees - Sixtyfivedegrees   9 -  25       1
#  ACME Restaurant               5 -  51       1
#  Agave Cafe                    30 -  300     1
#  Al Bustan Restaurant          199 -  214    1
#  Al Dana Restaurant            175 -  200    1
# dtype: int64
